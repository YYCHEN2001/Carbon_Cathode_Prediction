# %%
import pandas as pd

data = pd.read_csv('data/dataset_reduced.csv')
data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data['target_class'] = pd.qcut(data['Cs'], q=10, labels=False)
X = data.drop(['Cs', 'target_class'], axis=1)
y = data['Cs']
stratify_column = data['target_class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=stratify_column)

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)

X_train_scaled, X_test_scaled, y_train, y_test
# Out:
# (            O         N  Specific surface area  Pore volume       Dap  \
#  0    1.526124 -0.131350               1.510823     0.656866 -0.569079
#  1   -0.297092 -1.055675              -1.096975    -1.380955 -1.013188
#  2    1.526124 -0.131350               1.510823     0.656866 -0.569079
#  3   -0.148258 -0.202180               0.809291     1.271787  0.277967
#  4   -0.952892 -0.439458              -0.133456     1.629300  1.884198
#  ..        ...       ...                    ...          ...       ...
#  500 -0.148258 -0.202180               0.809291     1.271787  0.277967
#  501 -0.597086 -0.081769              -0.541288     2.515931  4.299486
#  502 -1.306373 -1.055675               1.637461     3.070790  0.796522
#  503 -0.520343 -0.290716               0.644215     0.070546 -0.545793
#  504  0.151735  0.162592              -0.181253    -0.518635 -0.539042
#
#          ID/IG  Current density    micro%
#  0   -0.338649        -0.262134  0.475445
#  1   -0.415250        -0.305643  0.748024
#  2   -0.338649         3.871269  0.475445
#  3    1.269960        -0.044586 -0.030975
#  4   -0.553131        -0.262134 -1.376341
#  ..        ...              ...       ...
#  500  1.269960        -0.436172 -0.030975
#  501 -0.491850        -0.457927 -1.591106
#  502 -0.338649        -0.044586 -1.462490
#  503 -0.691011        -0.436172 -0.197231
#  504 -0.370821        -0.392663  0.877566
#
#  [505 rows x 8 columns],
#              O         N  Specific surface area  Pore volume       Dap  \
#  0    1.226131 -0.411126               1.540752     0.599664 -0.616434
#  1    0.421497  0.962965              -0.371098    -0.644479 -0.523824
#  2    1.374965  0.042182              -1.302454    -0.601578  1.707126
#  3    0.907533  0.024475               1.606527     0.928575 -0.448310
#  4    0.640097  1.306488              -0.094147     0.013344 -0.012472
#  ..        ...       ...                    ...          ...       ...
#  122 -0.971497 -0.669654              -0.908917     0.556763  2.609892
#  123  0.907533  0.024475               1.606527     0.928575 -0.448310
#  124 -0.350580 -0.110101               1.973040     1.130212 -0.490938
#  125 -0.769175 -0.527995              -0.163273     0.184950  0.265685
#  126 -0.648248 -0.489039               1.010627     0.699768 -0.286483
#
#          ID/IG  Current density    micro%
#  0   -0.301881        -0.457927  0.306935
#  1   -0.292689        -0.392663 -1.424582
#  2   -0.427506        -0.457927 -1.243781
#  3   -0.461210        -0.457927  0.155531
#  4    4.839541        -0.457927 -0.177748
#  ..        ...              ...       ...
#  122 -0.645051        -0.436172 -1.148619
#  123 -0.461210        -0.305643  0.155531
#  124  2.373007        -0.457927 -0.755591
#  125 -0.445890        -0.436172 -0.502967
#  126 -0.234473         0.390509 -0.496863
#
#  [127 rows x 8 columns],
#  484    106.7
#  145     34.8
#  491     59.4
#  463    116.7
#  216     89.9
#         ...
#  460    138.4
#  224     59.8
#  375     67.9
#  340     99.2
#  124     90.4
#  Name: Specific capacity, Length: 505, dtype: float64,
#  612     93.5
#  273     72.2
#  56      69.7
#  494    174.3
#  320    189.9
#         ...
#  201     84.9
#  498    141.2
#  588    199.1
#  36      71.6
#  529     96.7
#  Name: Specific capacity, Length: 127, dtype: float64)

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, root_mean_squared_error

def calculate_metrics(y_true, y_pred):
    """
    Calculate and return actual vs pred fig for data_dopants metrics.
    """
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)*100
    rmse = root_mean_squared_error(y_true, y_pred)
    return r2, mae, mape, rmse


def metrics_to_dataframe(y_train, y_train_pred, y_test, y_test_pred, model_name):
    R2_train, MAE_train, MAPE_train, RMSE_train = calculate_metrics(y_train, y_train_pred)
    R2_test, MAE_test, MAPE_test, RMSE_test = calculate_metrics(y_test, y_test_pred)
    metrics = {'model': model_name,
                   'R2_train': R2_train, 'MAE_train': MAE_train, 'MAPE_train': MAPE_train, 'RMSE_train': RMSE_train,
                   'R2_test': R2_test, 'MAE_test': MAE_test, 'MAPE_test': MAPE_test, 'RMSE_test': RMSE_test}
    model_name_df = pd.DataFrame([metrics])
    return model_name_df

def plot_actual_vs_predicted(y_train, y_pred_train, y_test, y_pred_test, figpath=None):
    """
    Plot the actual vs predicted values for both training and test sets,
    and plot y=x as the fit line.
    """
    # 设置全局字体为Times New Roman，字号为32，字体粗细为粗体
    plt.rcParams.update({
        'font.family': 'Times New Roman',
        'font.size': 32,
        'font.weight': 'bold',
        'figure.figsize': (10, 10)  # 设置图像尺寸为10x10英寸
    })

    # 绘制训练集和测试集的散点图
    plt.scatter(y_train, y_pred_train, color='blue', label='Train', s=50, alpha=0.5)
    plt.scatter(y_test, y_pred_test, color='red', label='Test', s=50, alpha=0.5)

    # 计算合并数据的最小值和最大值，用于设置坐标轴范围和绘制y=x线
    y_pred_train = y_pred_train.ravel()
    y_pred_test = y_pred_test.ravel()
    y_combined = np.concatenate([y_train, y_pred_train, y_test, y_pred_test])
    min_val, max_val = np.min(y_combined), np.max(y_combined)
    padding = (max_val - min_val) * 0.05
    padded_min, padded_max = min_val - padding, max_val + padding

    # 绘制y=x的虚线，线宽为3
    plt.plot([padded_min, padded_max], [padded_min, padded_max], 'k--', lw=3, label='Regression Line')

    # 设置标题和轴标签，明确指定加粗
    plt.title('Actual vs Predicted Values', fontweight='bold', pad=20) # pad=20避免标题和轴线重合
    plt.xlabel('Actual Values', fontweight='bold')
    plt.ylabel('Predicted Values', fontweight='bold')

    # 设置图例，无边框，位于左上角
    plt.legend(frameon=False, loc='upper left', fontsize=28)

    # 设置坐标轴为相同比例，并且坐标轴范围一致
    plt.axis('equal')
    plt.xlim([padded_min, padded_max])
    plt.ylim([padded_min, padded_max])

    # 设置刻度线的长度和粗细
    plt.tick_params(axis='both', which='major', length=10, width=2, labelsize=32)

    # 检查并统一X轴和Y轴的刻度
    # 可以通过设置两个轴的相同刻度，或者根据数据自动选择刻度
    x_ticks = np.arange(0, max(y_combined) + 1, 50)  # 可以根据数据范围调整
    y_ticks = np.arange(0, max(y_combined) + 1, 50)  # 使得X和Y轴的刻度间隔相同

    plt.xticks(x_ticks)
    plt.yticks(y_ticks)

    # 设置图形边界的宽度和可见性
    for spine in plt.gca().spines.values():
        spine.set_visible(True)
        spine.set_linewidth(2.5)
        spine.set_color('black')

    # 保存图像，背景透明，紧凑布局
    plt.savefig(figpath, bbox_inches='tight', transparent=True, dpi=300)
    plt.show()

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
y_train_pred = lr.predict(X_train_scaled)
y_test_pred = lr.predict(X_test_scaled)

lr_metrics = metrics_to_dataframe(y_train, y_train_pred, y_test, y_test_pred, 'Linear Regression')
plot_actual_vs_predicted(y_train, y_train_pred, y_test, y_test_pred, 'output/figures/lr_reduced.png')

lr_metrics
# Out:
#                model  R2_train  MAE_train  MAPE_train  RMSE_train  R2_test  \
# 0  Linear Regression  0.368366   23.53142   34.331034   31.197682  0.45277
#
#     MAE_test  MAPE_test  RMSE_test
# 0  22.477543  32.641922  29.215163

# %%
from sklearn.svm import SVR

svr = SVR(C=5, kernel='poly', degree=6, gamma='scale', coef0=6, epsilon=0.75, verbose=True)
svr.fit(X_train_scaled, y_train)

y_train_pred = svr.predict(X_train_scaled)
y_test_pred = svr.predict(X_test_scaled)

svr_metrics = metrics_to_dataframe(y_train, y_train_pred, y_test, y_test_pred, 'SVR')
plot_actual_vs_predicted(y_train, y_train_pred, y_test, y_test_pred, 'output/figures/svr_reduced.png')

svr_metrics
# Out:
# [LibSVM]
#   model  R2_train  MAE_train  MAPE_train  RMSE_train   R2_test  MAE_test  \
# 0   SVR   0.90725   6.086613    5.642222   11.954914  0.868283  9.288821
#
#    MAPE_test  RMSE_test
# 0  11.029474  14.333248

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=80,
                            max_depth=13,
                            min_samples_leaf=1,
                            min_samples_split=2,
                            random_state=21)
rfr.fit(X_train_scaled, y_train)

y_train_pred = rfr.predict(X_train_scaled)
y_test_pred = rfr.predict(X_test_scaled)

rfr_metrics = metrics_to_dataframe(y_train, y_train_pred, y_test, y_test_pred, 'Randon Forest')
plot_actual_vs_predicted(y_train, y_train_pred, y_test, y_test_pred, 'output/figures/rfr_reduced.png')

rfr_metrics
# Out:
#            model  R2_train  MAE_train  MAPE_train  RMSE_train   R2_test  \
# 0  Randon Forest  0.980705   3.625796    4.760953    5.452702  0.911245
#
#    MAE_test  MAPE_test  RMSE_test
# 0  7.856233  10.296883  11.765769

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(n_estimators=80,
                                alpha=0.01,
                                learning_rate=0.25,
                                max_depth=9,
                                max_features=0.3,
                                min_samples_leaf=3,
                                min_samples_split=7,
                                subsample=0.7,
                                random_state=21)
gbr.fit(X_train_scaled, y_train)

y_train_pred = gbr.predict(X_train_scaled)
y_test_pred = gbr.predict(X_test_scaled)

gbr_metrics = metrics_to_dataframe(y_train, y_train_pred, y_test, y_test_pred, 'GBR')
plot_actual_vs_predicted(y_train, y_train_pred, y_test, y_test_pred, 'output/figures/gbr_reduced.png')

gbr_metrics
# Out:
#   model  R2_train  MAE_train  MAPE_train  RMSE_train   R2_test  MAE_test  \
# 0   GBR  0.997963   1.265646     1.58338    1.771753  0.964033  5.009957
#
#    MAPE_test  RMSE_test
# 0    6.06153   7.489926

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(n_estimators=80,
                   learning_rate=0.2,
                   subsample=0.5,
                   gamma=0.1,
                   max_depth=8,
                   min_child_weight=2,
                   reg_alpha=0.26,
                   colsample_bytree=0.7,
                   colsample_bylevel=1.0,
                   colsample_bynode=0.5,
                   random_state=21)
xgb.fit(X_train_scaled, y_train)

y_train_pred = xgb.predict(X_train_scaled)
y_test_pred = xgb.predict(X_test_scaled)

xgb_metrics = metrics_to_dataframe(y_train, y_train_pred, y_test, y_test_pred, 'XGBoost')
plot_actual_vs_predicted(y_train, y_train_pred, y_test, y_test_pred, 'output/figures/XGB_reduced.png')

xgb_metrics
# Out:
#      model  R2_train  MAE_train  MAPE_train  RMSE_train   R2_test  MAE_test  \
# 0  XGBoost  0.994633   2.051741    2.642526    2.875845  0.967404  5.349314
#
#    MAPE_test  RMSE_test
# 0   6.850985   7.130297

# %%
from keras import Input
from keras.layers import Dense
from keras.models import Sequential
from keras.callbacks import EarlyStopping

model = Sequential([
    Input(shape=(X_train_scaled.shape[1],)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)
])

# 编译模型，指定优化器、损失函数和评价指标
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# 初始化早停回调
early_stopper = EarlyStopping(
    monitor='val_loss',     # 监控验证集损失
    min_delta=0.001,        # 表示监控指标至少需要改善 0.001
    patience=50,            # 如果30个epoch内验证集损失没有改善，则提前停止训练
    verbose=1,              # 输出早停信息
    mode='min',             # 监控的指标是损失，应该减小
    restore_best_weights=True  # 训练结束后，模型权重回滚到最佳状态
)

# 训练模型
history = model.fit(
    X_train_scaled, y_train,
    validation_split=0.3,  # 使用20%的数据作为验证集
    epochs=1000,  # 最大训练轮数
    callbacks=[early_stopper],  # 使用早停机制
    verbose=1  # 输出训练信息
)
# 预测训练集和测试集
y_train_pred = model.predict(X_train_scaled).flatten()
y_test_pred = model.predict(X_test_scaled).flatten()

ann_metrics = metrics_to_dataframe(y_train, y_train_pred, y_test, y_test_pred, 'ANN')
plot_actual_vs_predicted(y_train, y_train_pred, y_test, y_test_pred, 'output/figures/ann_reduced.png')

ann_metrics
# Out:
# Epoch 1/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 10288.7383 - mae: 94.0335 - val_loss: 10957.7402 - val_mae: 96.3472
# Epoch 2/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9964.2275 - mae: 91.2260 - val_loss: 10022.8662 - val_mae: 91.1191
# Epoch 3/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8784.2363 - mae: 84.7232 - val_loss: 6907.6816 - val_mae: 71.9241
# Epoch 4/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4942.7856 - mae: 59.1216 - val_loss: 2610.4187 - val_mae: 39.4562
# Epoch 5/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2217.1489 - mae: 37.0771 - val_loss: 2141.0093 - val_mae: 35.4476
# Epoch 6/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1581.5671 - mae: 30.9137 - val_loss: 2117.3574 - val_mae: 35.1932
# Epoch 7/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1463.9524 - mae: 29.5550 - val_loss: 1832.0742 - val_mae: 32.4554
# Epoch 8/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1273.0771 - mae: 28.0172 - val_loss: 1744.5481 - val_mae: 31.6974
# Epoch 9/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1136.1578 - mae: 26.4737 - val_loss: 1666.8970 - val_mae: 31.0460
# Epoch 10/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1073.3671 - mae: 25.7224 - val_loss: 1638.9730 - val_mae: 30.7375
# Epoch 11/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 859.2181 - mae: 22.6628 - val_loss: 1585.0790 - val_mae: 30.3746
# Epoch 12/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 916.4351 - mae: 23.8282 - val_loss: 1519.4110 - val_mae: 29.6265
# Epoch 13/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 892.4225 - mae: 23.6801 - val_loss: 1438.1721 - val_mae: 28.8745
# Epoch 14/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 852.3518 - mae: 22.9652 - val_loss: 1401.7256 - val_mae: 28.4796
# Epoch 15/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 820.4325 - mae: 22.3151 - val_loss: 1371.9225 - val_mae: 28.1229
# Epoch 16/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1001.3376 - mae: 24.7871 - val_loss: 1363.1307 - val_mae: 27.9125
# Epoch 17/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 807.4707 - mae: 22.5334 - val_loss: 1365.3275 - val_mae: 27.7997
# Epoch 18/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 907.1472 - mae: 23.3368 - val_loss: 1340.9170 - val_mae: 27.7290
# Epoch 19/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 898.7822 - mae: 23.7723 - val_loss: 1309.0817 - val_mae: 27.1771
# Epoch 20/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 755.3147 - mae: 21.9877 - val_loss: 1257.0864 - val_mae: 26.8017
# Epoch 21/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 824.3911 - mae: 22.7079 - val_loss: 1239.6995 - val_mae: 26.5001
# Epoch 22/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 811.5389 - mae: 22.2994 - val_loss: 1207.2039 - val_mae: 26.1382
# Epoch 23/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 710.3535 - mae: 20.8316 - val_loss: 1194.8130 - val_mae: 25.8078
# Epoch 24/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 695.0491 - mae: 20.5299 - val_loss: 1177.3867 - val_mae: 25.6436
# Epoch 25/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 635.2269 - mae: 19.7741 - val_loss: 1181.2726 - val_mae: 25.5305
# Epoch 26/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 670.7343 - mae: 20.2124 - val_loss: 1163.1707 - val_mae: 25.3850
# Epoch 27/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 708.4422 - mae: 21.1503 - val_loss: 1109.4453 - val_mae: 24.8197
# Epoch 28/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 698.1817 - mae: 20.2905 - val_loss: 1160.8134 - val_mae: 25.2485
# Epoch 29/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 642.2507 - mae: 19.5020 - val_loss: 1115.5750 - val_mae: 25.0784
# Epoch 30/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 683.2966 - mae: 19.9677 - val_loss: 1064.0090 - val_mae: 24.3258
# Epoch 31/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 647.6852 - mae: 19.1145 - val_loss: 1034.3099 - val_mae: 24.3201
# Epoch 32/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 599.0895 - mae: 18.9490 - val_loss: 1060.0551 - val_mae: 23.9525
# Epoch 33/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 627.3879 - mae: 18.7154 - val_loss: 1039.6149 - val_mae: 23.7036
# Epoch 34/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 673.5799 - mae: 19.4867 - val_loss: 982.3530 - val_mae: 23.8772
# Epoch 35/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 620.7452 - mae: 20.3754 - val_loss: 1017.0203 - val_mae: 23.5741
# Epoch 36/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 570.4725 - mae: 18.4693 - val_loss: 990.0054 - val_mae: 23.6151
# Epoch 37/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 571.5093 - mae: 18.7078 - val_loss: 1001.6639 - val_mae: 23.3481
# Epoch 38/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 562.3524 - mae: 18.4893 - val_loss: 946.9566 - val_mae: 23.1154
# Epoch 39/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 558.9208 - mae: 18.5939 - val_loss: 951.8447 - val_mae: 22.6831
# Epoch 40/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 554.8084 - mae: 18.1291 - val_loss: 925.3211 - val_mae: 22.8509
# Epoch 41/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 536.6239 - mae: 17.8468 - val_loss: 956.6358 - val_mae: 22.6874
# Epoch 42/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 536.4099 - mae: 17.1941 - val_loss: 891.1501 - val_mae: 22.7550
# Epoch 43/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 586.7175 - mae: 19.7618 - val_loss: 947.8331 - val_mae: 22.3535
# Epoch 44/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 495.3234 - mae: 16.6616 - val_loss: 871.5989 - val_mae: 22.3734
# Epoch 45/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 591.3477 - mae: 19.0553 - val_loss: 917.5909 - val_mae: 21.6148
# Epoch 46/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 464.5610 - mae: 16.1160 - val_loss: 869.3682 - val_mae: 22.5419
# Epoch 47/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 517.7864 - mae: 17.8299 - val_loss: 947.6698 - val_mae: 21.7223
# Epoch 48/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 488.8860 - mae: 16.3027 - val_loss: 834.1104 - val_mae: 22.0647
# Epoch 49/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 508.9429 - mae: 17.6380 - val_loss: 897.4510 - val_mae: 21.4503
# Epoch 50/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 547.1097 - mae: 17.1856 - val_loss: 847.7130 - val_mae: 21.8820
# Epoch 51/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 464.7166 - mae: 16.0561 - val_loss: 827.2839 - val_mae: 20.7796
# Epoch 52/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 427.0008 - mae: 15.3018 - val_loss: 785.0421 - val_mae: 20.6916
# Epoch 53/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 421.2915 - mae: 15.6145 - val_loss: 789.5530 - val_mae: 20.6204
# Epoch 54/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 473.4352 - mae: 16.4012 - val_loss: 871.6760 - val_mae: 21.7934
# Epoch 55/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 459.8640 - mae: 16.0191 - val_loss: 791.9272 - val_mae: 20.8563
# Epoch 56/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 411.5876 - mae: 15.0270 - val_loss: 760.8576 - val_mae: 20.4827
# Epoch 57/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 425.4994 - mae: 15.2998 - val_loss: 792.8357 - val_mae: 20.0765
# Epoch 58/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 412.5464 - mae: 14.5997 - val_loss: 753.8426 - val_mae: 19.8237
# Epoch 59/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 435.7200 - mae: 15.1488 - val_loss: 744.1397 - val_mae: 19.8748
# Epoch 60/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 389.4476 - mae: 14.9097 - val_loss: 731.5471 - val_mae: 19.4754
# Epoch 61/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 347.5559 - mae: 13.7479 - val_loss: 721.9316 - val_mae: 19.4891
# Epoch 62/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 382.1590 - mae: 13.7501 - val_loss: 739.7031 - val_mae: 19.8294
# Epoch 63/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 357.2857 - mae: 13.9828 - val_loss: 726.2409 - val_mae: 20.6552
# Epoch 64/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 387.0651 - mae: 14.8983 - val_loss: 803.7635 - val_mae: 19.8385
# Epoch 65/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 384.0917 - mae: 13.9211 - val_loss: 720.4246 - val_mae: 20.1898
# Epoch 66/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 365.0396 - mae: 14.0209 - val_loss: 728.6382 - val_mae: 19.6138
# Epoch 67/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 340.9218 - mae: 13.8290 - val_loss: 718.8536 - val_mae: 19.3229
# Epoch 68/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 333.4295 - mae: 13.4202 - val_loss: 730.1462 - val_mae: 18.6193
# Epoch 69/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322.6211 - mae: 12.7853 - val_loss: 712.0515 - val_mae: 19.7264
# Epoch 70/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 363.7663 - mae: 13.9569 - val_loss: 727.3879 - val_mae: 19.6436
# Epoch 71/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 341.7785 - mae: 13.8070 - val_loss: 712.6202 - val_mae: 18.9256
# Epoch 72/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 366.2044 - mae: 13.7540 - val_loss: 654.6326 - val_mae: 18.9317
# Epoch 73/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 278.4517 - mae: 12.5522 - val_loss: 704.0694 - val_mae: 18.6284
# Epoch 74/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 295.0710 - mae: 12.4469 - val_loss: 671.1695 - val_mae: 18.2193
# Epoch 75/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 365.2164 - mae: 13.6558 - val_loss: 717.2615 - val_mae: 20.5434
# Epoch 76/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 382.0432 - mae: 14.9805 - val_loss: 720.5327 - val_mae: 18.5783
# Epoch 77/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 330.0936 - mae: 13.4189 - val_loss: 644.2347 - val_mae: 18.5951
# Epoch 78/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 270.7937 - mae: 12.4644 - val_loss: 641.2922 - val_mae: 18.3613
# Epoch 79/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 313.2069 - mae: 13.1486 - val_loss: 658.7870 - val_mae: 17.9938
# Epoch 80/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 278.4605 - mae: 12.4073 - val_loss: 659.6519 - val_mae: 17.8693
# Epoch 81/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 272.8541 - mae: 12.1284 - val_loss: 671.4266 - val_mae: 20.6252
# Epoch 82/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 381.6210 - mae: 15.1791 - val_loss: 684.9017 - val_mae: 18.0420
# Epoch 83/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 315.5158 - mae: 12.9900 - val_loss: 626.6798 - val_mae: 18.1037
# Epoch 84/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 268.9698 - mae: 12.1027 - val_loss: 615.3434 - val_mae: 18.6174
# Epoch 85/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 281.4146 - mae: 12.2937 - val_loss: 684.3614 - val_mae: 17.8497
# Epoch 86/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 272.2637 - mae: 12.1512 - val_loss: 627.3095 - val_mae: 18.9115
# Epoch 87/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 321.0693 - mae: 13.0788 - val_loss: 666.8088 - val_mae: 19.7128
# Epoch 88/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 482.7296 - mae: 16.3693 - val_loss: 878.9961 - val_mae: 20.2783
# Epoch 89/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 394.2685 - mae: 15.1833 - val_loss: 582.4651 - val_mae: 17.5422
# Epoch 90/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 273.7090 - mae: 12.1179 - val_loss: 638.4471 - val_mae: 17.4947
# Epoch 91/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 297.8461 - mae: 12.3736 - val_loss: 600.5526 - val_mae: 17.6004
# Epoch 92/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 279.5596 - mae: 12.1200 - val_loss: 615.5646 - val_mae: 17.4227
# Epoch 93/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 274.3855 - mae: 11.7922 - val_loss: 566.5314 - val_mae: 16.9950
# Epoch 94/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 229.7333 - mae: 11.1002 - val_loss: 586.9598 - val_mae: 17.5093
# Epoch 95/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 247.8448 - mae: 11.3473 - val_loss: 580.9877 - val_mae: 16.9745
# Epoch 96/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 248.7231 - mae: 11.6097 - val_loss: 581.1518 - val_mae: 16.7326
# Epoch 97/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 242.4548 - mae: 11.4379 - val_loss: 535.9818 - val_mae: 17.1149
# Epoch 98/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 236.0678 - mae: 11.5251 - val_loss: 618.7941 - val_mae: 16.9024
# Epoch 99/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 225.5306 - mae: 11.2199 - val_loss: 597.7670 - val_mae: 17.1361
# Epoch 100/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 265.4661 - mae: 11.6833 - val_loss: 536.3224 - val_mae: 16.2399
# Epoch 101/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 258.7745 - mae: 11.6824 - val_loss: 571.5526 - val_mae: 16.8989
# Epoch 102/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 238.6523 - mae: 11.3092 - val_loss: 584.4363 - val_mae: 16.3636
# Epoch 103/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 219.4610 - mae: 11.0499 - val_loss: 517.7375 - val_mae: 15.8888
# Epoch 104/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 206.7148 - mae: 10.5702 - val_loss: 527.1831 - val_mae: 16.3044
# Epoch 105/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 220.3298 - mae: 10.6680 - val_loss: 561.3337 - val_mae: 15.9477
# Epoch 106/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 293.8386 - mae: 12.1965 - val_loss: 601.9019 - val_mae: 19.4797
# Epoch 107/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 268.7757 - mae: 12.6733 - val_loss: 540.1293 - val_mae: 16.7691
# Epoch 108/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 220.2605 - mae: 11.0962 - val_loss: 520.2944 - val_mae: 15.8155
# Epoch 109/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 253.6294 - mae: 11.6074 - val_loss: 511.1751 - val_mae: 15.2983
# Epoch 110/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 191.4377 - mae: 9.9839 - val_loss: 483.5576 - val_mae: 16.2725
# Epoch 111/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 252.3328 - mae: 12.1531 - val_loss: 509.1541 - val_mae: 16.3835
# Epoch 112/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 220.4165 - mae: 11.1115 - val_loss: 496.5048 - val_mae: 17.0188
# Epoch 113/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 464.7652 - mae: 16.4477 - val_loss: 860.2452 - val_mae: 21.3064
# Epoch 114/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 371.2368 - mae: 13.9604 - val_loss: 497.2363 - val_mae: 16.3476
# Epoch 115/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 268.0188 - mae: 11.9377 - val_loss: 535.7277 - val_mae: 17.6679
# Epoch 116/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 253.9971 - mae: 11.9192 - val_loss: 553.9229 - val_mae: 15.5976
# Epoch 117/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 196.1937 - mae: 9.9440 - val_loss: 503.8934 - val_mae: 15.5972
# Epoch 118/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 224.0929 - mae: 10.8182 - val_loss: 518.7205 - val_mae: 16.7681
# Epoch 119/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 214.3658 - mae: 10.6453 - val_loss: 471.8076 - val_mae: 15.0673
# Epoch 120/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 207.9135 - mae: 10.8101 - val_loss: 480.7028 - val_mae: 14.9222
# Epoch 121/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 170.6054 - mae: 9.6018 - val_loss: 488.6858 - val_mae: 14.9482
# Epoch 122/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 158.2542 - mae: 9.2001 - val_loss: 490.3976 - val_mae: 14.8004
# Epoch 123/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 183.7310 - mae: 9.5777 - val_loss: 503.8191 - val_mae: 15.1107
# Epoch 124/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 220.3061 - mae: 10.6350 - val_loss: 499.7587 - val_mae: 15.2692
# Epoch 125/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 184.2594 - mae: 9.4752 - val_loss: 463.3168 - val_mae: 15.8328
# Epoch 126/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 174.7468 - mae: 9.9827 - val_loss: 532.2628 - val_mae: 15.3445
# Epoch 127/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 264.8326 - mae: 11.5090 - val_loss: 526.3376 - val_mae: 18.1872
# Epoch 128/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 237.8218 - mae: 11.9186 - val_loss: 531.4727 - val_mae: 15.5484
# Epoch 129/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 174.4242 - mae: 10.0575 - val_loss: 495.3616 - val_mae: 14.9570
# Epoch 130/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 183.1861 - mae: 9.6653 - val_loss: 472.3622 - val_mae: 15.6153
# Epoch 131/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 160.2746 - mae: 8.7880 - val_loss: 447.4234 - val_mae: 14.5159
# Epoch 132/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 183.0114 - mae: 9.9747 - val_loss: 513.9293 - val_mae: 14.8225
# Epoch 133/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 190.6225 - mae: 10.0192 - val_loss: 446.6314 - val_mae: 14.3355
# Epoch 134/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 174.2977 - mae: 9.4515 - val_loss: 487.4169 - val_mae: 14.6243
# Epoch 135/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 207.5682 - mae: 10.1533 - val_loss: 526.5858 - val_mae: 17.2111
# Epoch 136/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 219.4945 - mae: 11.2486 - val_loss: 498.6481 - val_mae: 15.1781
# Epoch 137/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 168.4434 - mae: 9.2891 - val_loss: 498.8600 - val_mae: 14.9401
# Epoch 138/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 173.3831 - mae: 9.6606 - val_loss: 545.5002 - val_mae: 15.2861
# Epoch 139/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 186.6007 - mae: 9.4165 - val_loss: 503.7987 - val_mae: 15.2115
# Epoch 140/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 205.0830 - mae: 9.8108 - val_loss: 486.2311 - val_mae: 15.5228
# Epoch 141/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 218.5789 - mae: 11.5947 - val_loss: 481.8334 - val_mae: 15.0733
# Epoch 142/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 180.4325 - mae: 10.0296 - val_loss: 533.6320 - val_mae: 14.9579
# Epoch 143/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 218.4962 - mae: 10.1287 - val_loss: 440.4830 - val_mae: 14.2716
# Epoch 144/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 157.8006 - mae: 8.5233 - val_loss: 441.8691 - val_mae: 14.2411
# Epoch 145/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 151.7291 - mae: 8.9623 - val_loss: 468.5847 - val_mae: 14.2959
# Epoch 146/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 195.8615 - mae: 9.4600 - val_loss: 499.9372 - val_mae: 15.3429
# Epoch 147/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 189.5539 - mae: 10.6156 - val_loss: 497.6330 - val_mae: 14.5695
# Epoch 148/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 191.5367 - mae: 9.6432 - val_loss: 474.2877 - val_mae: 14.6648
# Epoch 149/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 173.4679 - mae: 9.0109 - val_loss: 458.2704 - val_mae: 13.8267
# Epoch 150/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 160.9695 - mae: 8.7871 - val_loss: 447.8398 - val_mae: 15.0113
# Epoch 151/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 175.4662 - mae: 9.7954 - val_loss: 456.7851 - val_mae: 15.3707
# Epoch 152/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 159.3716 - mae: 9.8066 - val_loss: 502.8007 - val_mae: 14.8383
# Epoch 153/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 147.4547 - mae: 8.8704 - val_loss: 438.0650 - val_mae: 14.5843
# Epoch 154/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 187.4173 - mae: 9.8411 - val_loss: 489.6044 - val_mae: 14.3361
# Epoch 155/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 190.7013 - mae: 9.5012 - val_loss: 476.3070 - val_mae: 14.3660
# Epoch 156/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 162.8876 - mae: 9.0766 - val_loss: 443.7031 - val_mae: 14.8745
# Epoch 157/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 137.0319 - mae: 8.6117 - val_loss: 428.2533 - val_mae: 14.2150
# Epoch 158/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 138.4175 - mae: 8.6468 - val_loss: 436.0037 - val_mae: 14.7554
# Epoch 159/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 143.1832 - mae: 8.5101 - val_loss: 422.3275 - val_mae: 13.6234
# Epoch 160/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 171.7099 - mae: 9.4811 - val_loss: 520.2803 - val_mae: 16.1642
# Epoch 161/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 529.0579 - mae: 16.0024 - val_loss: 806.1883 - val_mae: 20.2011
# Epoch 162/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 323.2118 - mae: 14.0843 - val_loss: 460.9623 - val_mae: 15.7389
# Epoch 163/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 196.3570 - mae: 10.6901 - val_loss: 521.9291 - val_mae: 16.9408
# Epoch 164/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 180.3245 - mae: 10.2395 - val_loss: 507.6444 - val_mae: 15.3401
# Epoch 165/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 175.0002 - mae: 9.6639 - val_loss: 480.8549 - val_mae: 14.8160
# Epoch 166/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 165.5066 - mae: 9.0979 - val_loss: 460.3484 - val_mae: 14.0732
# Epoch 167/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 132.6794 - mae: 8.1493 - val_loss: 454.3192 - val_mae: 15.5389
# Epoch 168/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 147.4951 - mae: 9.0452 - val_loss: 465.5925 - val_mae: 13.8789
# Epoch 169/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 137.2850 - mae: 8.0438 - val_loss: 460.8624 - val_mae: 14.0131
# Epoch 170/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 160.9198 - mae: 8.8744 - val_loss: 431.0975 - val_mae: 14.8465
# Epoch 171/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 124.8592 - mae: 8.1019 - val_loss: 432.0369 - val_mae: 13.5944
# Epoch 172/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 129.2403 - mae: 8.1514 - val_loss: 429.5378 - val_mae: 13.3956
# Epoch 173/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 104.8657 - mae: 7.1144 - val_loss: 419.4775 - val_mae: 14.4028
# Epoch 174/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 132.7664 - mae: 8.2939 - val_loss: 413.4738 - val_mae: 13.1663
# Epoch 175/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 133.7083 - mae: 8.0067 - val_loss: 445.5397 - val_mae: 13.5713
# Epoch 176/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 120.9237 - mae: 7.6953 - val_loss: 415.8007 - val_mae: 13.1900
# Epoch 177/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 144.4136 - mae: 8.2791 - val_loss: 440.8827 - val_mae: 13.9841
# Epoch 178/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 128.2682 - mae: 8.0024 - val_loss: 401.2984 - val_mae: 13.6616
# Epoch 179/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 119.7101 - mae: 7.5202 - val_loss: 403.5152 - val_mae: 13.2234
# Epoch 180/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 105.7152 - mae: 7.4007 - val_loss: 411.4648 - val_mae: 13.3268
# Epoch 181/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 133.2210 - mae: 7.9269 - val_loss: 454.3830 - val_mae: 13.5789
# Epoch 182/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 115.6870 - mae: 7.4360 - val_loss: 402.8621 - val_mae: 14.2032
# Epoch 183/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 117.1509 - mae: 7.6731 - val_loss: 409.7927 - val_mae: 14.0418
# Epoch 184/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 127.9988 - mae: 8.4330 - val_loss: 430.7213 - val_mae: 13.8017
# Epoch 185/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 123.1813 - mae: 7.9266 - val_loss: 425.5696 - val_mae: 13.0466
# Epoch 186/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 118.0428 - mae: 7.2993 - val_loss: 404.1745 - val_mae: 13.4710
# Epoch 187/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 116.4892 - mae: 7.3685 - val_loss: 423.8466 - val_mae: 14.0187
# Epoch 188/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 178.1042 - mae: 9.4647 - val_loss: 470.1267 - val_mae: 14.5514
# Epoch 189/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 148.5399 - mae: 9.1449 - val_loss: 439.9562 - val_mae: 13.2773
# Epoch 190/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 116.1717 - mae: 7.1884 - val_loss: 403.1357 - val_mae: 13.3609
# Epoch 191/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 101.7149 - mae: 6.9626 - val_loss: 388.5160 - val_mae: 13.4023
# Epoch 192/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 116.4844 - mae: 7.6458 - val_loss: 444.4323 - val_mae: 13.5244
# Epoch 193/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 127.4990 - mae: 7.7415 - val_loss: 395.1651 - val_mae: 12.6964
# Epoch 194/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 117.6950 - mae: 7.2986 - val_loss: 401.3357 - val_mae: 12.8683
# Epoch 195/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 102.9323 - mae: 7.1757 - val_loss: 380.4995 - val_mae: 13.2472
# Epoch 196/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 159.5089 - mae: 8.8373 - val_loss: 409.5830 - val_mae: 14.3596
# Epoch 197/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 140.8633 - mae: 9.0293 - val_loss: 504.8586 - val_mae: 14.7630
# Epoch 198/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 160.4446 - mae: 9.0072 - val_loss: 399.2055 - val_mae: 13.2730
# Epoch 199/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 124.2176 - mae: 7.7526 - val_loss: 431.8522 - val_mae: 14.5718
# Epoch 200/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 229.5482 - mae: 10.1401 - val_loss: 408.5045 - val_mae: 14.1988
# Epoch 201/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 148.7106 - mae: 9.0390 - val_loss: 435.0850 - val_mae: 13.9441
# Epoch 202/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 133.7315 - mae: 8.0156 - val_loss: 398.9796 - val_mae: 12.9720
# Epoch 203/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 133.0028 - mae: 8.6003 - val_loss: 428.3468 - val_mae: 13.0806
# Epoch 204/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 118.6583 - mae: 7.8317 - val_loss: 403.2148 - val_mae: 12.7816
# Epoch 205/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 138.5515 - mae: 8.1182 - val_loss: 425.2346 - val_mae: 13.6562
# Epoch 206/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 173.7231 - mae: 9.0524 - val_loss: 456.8891 - val_mae: 13.7708
# Epoch 207/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 135.2177 - mae: 7.9155 - val_loss: 398.0378 - val_mae: 12.8547
# Epoch 208/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 165.3644 - mae: 8.6587 - val_loss: 429.9013 - val_mae: 13.6028
# Epoch 209/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 146.8042 - mae: 8.7877 - val_loss: 504.2332 - val_mae: 14.6975
# Epoch 210/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 144.7293 - mae: 8.7644 - val_loss: 403.7901 - val_mae: 13.4505
# Epoch 211/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 96.6588 - mae: 6.9297 - val_loss: 396.7950 - val_mae: 13.2657
# Epoch 212/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 97.1662 - mae: 7.0496 - val_loss: 391.1273 - val_mae: 12.4650
# Epoch 213/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 100.0700 - mae: 6.5877 - val_loss: 406.7162 - val_mae: 12.8142
# Epoch 214/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 105.9716 - mae: 6.7842 - val_loss: 383.8019 - val_mae: 13.1737
# Epoch 215/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 99.6996 - mae: 6.8071 - val_loss: 394.9287 - val_mae: 12.6639
# Epoch 216/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 87.2583 - mae: 6.7025 - val_loss: 376.5772 - val_mae: 13.6359
# Epoch 217/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 134.6540 - mae: 8.7560 - val_loss: 411.7406 - val_mae: 13.1651
# Epoch 218/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 110.6591 - mae: 7.2065 - val_loss: 453.0287 - val_mae: 14.1704
# Epoch 219/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 165.7058 - mae: 9.2429 - val_loss: 367.4419 - val_mae: 13.5102
# Epoch 220/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 117.0858 - mae: 7.6699 - val_loss: 389.6603 - val_mae: 13.2894
# Epoch 221/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112.4259 - mae: 7.4308 - val_loss: 439.1354 - val_mae: 13.3782
# Epoch 222/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 102.9232 - mae: 7.1702 - val_loss: 450.4561 - val_mae: 13.4340
# Epoch 223/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 212.9215 - mae: 9.6803 - val_loss: 422.0284 - val_mae: 14.1190
# Epoch 224/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 220.5018 - mae: 10.3899 - val_loss: 373.0107 - val_mae: 14.0997
# Epoch 225/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 131.5404 - mae: 8.3053 - val_loss: 412.8604 - val_mae: 13.2898
# Epoch 226/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 114.3690 - mae: 6.8577 - val_loss: 376.9451 - val_mae: 12.6466
# Epoch 227/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 107.8467 - mae: 6.8861 - val_loss: 412.4935 - val_mae: 13.1994
# Epoch 228/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 92.9251 - mae: 6.6227 - val_loss: 364.2397 - val_mae: 12.5122
# Epoch 229/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 88.5852 - mae: 6.4900 - val_loss: 367.3773 - val_mae: 13.0466
# Epoch 230/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 92.3493 - mae: 6.5642 - val_loss: 369.4287 - val_mae: 12.3501
# Epoch 231/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 82.5765 - mae: 6.4489 - val_loss: 417.5700 - val_mae: 13.1828
# Epoch 232/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 228.3530 - mae: 9.9132 - val_loss: 426.7882 - val_mae: 15.1193
# Epoch 233/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 142.8736 - mae: 9.1364 - val_loss: 441.2607 - val_mae: 14.0776
# Epoch 234/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 127.4011 - mae: 8.2987 - val_loss: 416.8199 - val_mae: 13.1993
# Epoch 235/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 105.0999 - mae: 7.1794 - val_loss: 378.2996 - val_mae: 12.8870
# Epoch 236/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 108.3923 - mae: 6.9936 - val_loss: 389.6735 - val_mae: 14.8124
# Epoch 237/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 424.9057 - mae: 15.6993 - val_loss: 744.2662 - val_mae: 18.6279
# Epoch 238/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 240.2418 - mae: 11.1957 - val_loss: 497.5509 - val_mae: 14.5286
# Epoch 239/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 212.3184 - mae: 10.5090 - val_loss: 384.5502 - val_mae: 13.9949
# Epoch 240/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 132.6485 - mae: 8.3801 - val_loss: 351.5287 - val_mae: 12.3901
# Epoch 241/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 115.2537 - mae: 7.5627 - val_loss: 377.0890 - val_mae: 12.3732
# Epoch 242/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 89.1368 - mae: 6.4283 - val_loss: 352.1656 - val_mae: 11.9401
# Epoch 243/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 99.2090 - mae: 6.6460 - val_loss: 368.2580 - val_mae: 12.4243
# Epoch 244/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 88.4732 - mae: 6.4911 - val_loss: 384.3806 - val_mae: 12.2785
# Epoch 245/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 110.9848 - mae: 6.8124 - val_loss: 383.4564 - val_mae: 12.1674
# Epoch 246/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 117.6939 - mae: 7.3074 - val_loss: 356.8241 - val_mae: 12.2484
# Epoch 247/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 81.9277 - mae: 6.2731 - val_loss: 366.2765 - val_mae: 12.0916
# Epoch 248/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 102.4831 - mae: 6.7564 - val_loss: 375.3861 - val_mae: 12.2368
# Epoch 249/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 88.2922 - mae: 6.1755 - val_loss: 388.8461 - val_mae: 12.3711
# Epoch 250/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 104.5165 - mae: 6.6314 - val_loss: 382.1078 - val_mae: 12.2954
# Epoch 251/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 93.8891 - mae: 6.5128 - val_loss: 358.3901 - val_mae: 11.9340
# Epoch 252/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 85.6791 - mae: 6.2736 - val_loss: 380.0807 - val_mae: 12.1569
# Epoch 253/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 87.1367 - mae: 5.9178 - val_loss: 364.2400 - val_mae: 12.0335
# Epoch 254/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 89.2067 - mae: 6.2444 - val_loss: 360.5525 - val_mae: 12.0671
# Epoch 255/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 94.7224 - mae: 6.6507 - val_loss: 386.8685 - val_mae: 12.3997
# Epoch 256/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 80.7229 - mae: 5.8623 - val_loss: 376.8791 - val_mae: 12.0644
# Epoch 257/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 101.1006 - mae: 6.3316 - val_loss: 364.9762 - val_mae: 12.1256
# Epoch 258/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 80.4987 - mae: 5.7426 - val_loss: 361.2123 - val_mae: 12.0030
# Epoch 259/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.0234 - mae: 5.4275 - val_loss: 352.3089 - val_mae: 11.7102
# Epoch 260/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 82.3766 - mae: 6.1361 - val_loss: 375.1233 - val_mae: 12.2325
# Epoch 261/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.0350 - mae: 5.4025 - val_loss: 352.0987 - val_mae: 12.1166
# Epoch 262/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 86.7362 - mae: 6.4480 - val_loss: 373.3703 - val_mae: 12.5994
# Epoch 263/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 82.3177 - mae: 6.2035 - val_loss: 384.4158 - val_mae: 12.4852
# Epoch 264/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 95.2001 - mae: 6.9619 - val_loss: 337.1820 - val_mae: 12.1882
# Epoch 265/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 82.5449 - mae: 6.1938 - val_loss: 363.0140 - val_mae: 12.3936
# Epoch 266/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 76.9346 - mae: 5.8106 - val_loss: 347.6438 - val_mae: 11.8994
# Epoch 267/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 76.0118 - mae: 5.7464 - val_loss: 353.8395 - val_mae: 11.7946
# Epoch 268/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 82.3103 - mae: 5.8397 - val_loss: 349.4105 - val_mae: 12.3161
# Epoch 269/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 95.8359 - mae: 6.8933 - val_loss: 386.8643 - val_mae: 13.9098
# Epoch 270/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 170.9522 - mae: 9.6720 - val_loss: 397.1710 - val_mae: 13.2511
# Epoch 271/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 138.7429 - mae: 8.7304 - val_loss: 514.9791 - val_mae: 14.9503
# Epoch 272/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 144.8485 - mae: 8.7014 - val_loss: 358.9126 - val_mae: 12.3070
# Epoch 273/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 111.4324 - mae: 7.3185 - val_loss: 390.3216 - val_mae: 13.2352
# Epoch 274/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 98.4339 - mae: 6.8722 - val_loss: 371.8128 - val_mae: 12.9074
# Epoch 275/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 87.1076 - mae: 6.6710 - val_loss: 368.6142 - val_mae: 12.4807
# Epoch 276/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 77.2071 - mae: 5.7873 - val_loss: 346.3871 - val_mae: 11.7560
# Epoch 277/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.8181 - mae: 5.6836 - val_loss: 394.8416 - val_mae: 14.2655
# Epoch 278/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 410.3503 - mae: 13.5380 - val_loss: 627.5262 - val_mae: 16.5617
# Epoch 279/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 191.5999 - mae: 9.4686 - val_loss: 469.5854 - val_mae: 13.6659
# Epoch 280/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 160.1769 - mae: 8.7109 - val_loss: 445.7112 - val_mae: 13.3906
# Epoch 281/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 123.3172 - mae: 7.4705 - val_loss: 411.6220 - val_mae: 13.3507
# Epoch 282/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 109.1546 - mae: 6.9142 - val_loss: 380.8736 - val_mae: 12.8066
# Epoch 283/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 85.1847 - mae: 6.1500 - val_loss: 364.3150 - val_mae: 12.1973
# Epoch 284/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 70.5237 - mae: 5.8322 - val_loss: 347.3703 - val_mae: 12.0143
# Epoch 285/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 82.6176 - mae: 6.3704 - val_loss: 372.6475 - val_mae: 12.2299
# Epoch 286/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 71.1404 - mae: 5.6895 - val_loss: 369.8978 - val_mae: 12.2580
# Epoch 287/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 91.5480 - mae: 6.4076 - val_loss: 349.7931 - val_mae: 12.3325
# Epoch 288/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 76.2081 - mae: 5.9789 - val_loss: 349.6271 - val_mae: 12.2562
# Epoch 289/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 81.6574 - mae: 6.1539 - val_loss: 361.2849 - val_mae: 11.8553
# Epoch 290/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 101.4025 - mae: 6.6505 - val_loss: 381.4422 - val_mae: 12.6415
# Epoch 291/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 64.8857 - mae: 5.6421 - val_loss: 340.8126 - val_mae: 11.7934
# Epoch 292/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 77.4732 - mae: 5.8795 - val_loss: 379.9611 - val_mae: 12.4081
# Epoch 293/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 188.8881 - mae: 9.0185 - val_loss: 443.8547 - val_mae: 15.7710
# Epoch 294/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 149.2487 - mae: 9.2943 - val_loss: 389.7374 - val_mae: 13.6131
# Epoch 295/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 115.5732 - mae: 7.8302 - val_loss: 364.9582 - val_mae: 13.0474
# Epoch 296/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 89.4449 - mae: 6.8270 - val_loss: 368.6128 - val_mae: 12.0459
# Epoch 297/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69.3248 - mae: 5.5252 - val_loss: 345.7438 - val_mae: 11.8777
# Epoch 298/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 62.5318 - mae: 5.3876 - val_loss: 332.8597 - val_mae: 11.6074
# Epoch 299/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 72.4565 - mae: 5.6353 - val_loss: 342.4117 - val_mae: 12.3881
# Epoch 300/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.8330 - mae: 5.7598 - val_loss: 358.6650 - val_mae: 11.7473
# Epoch 301/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.2460 - mae: 5.4541 - val_loss: 327.1819 - val_mae: 11.8862
# Epoch 302/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 60.9141 - mae: 5.3211 - val_loss: 330.2184 - val_mae: 11.8154
# Epoch 303/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.5161 - mae: 5.3693 - val_loss: 346.3151 - val_mae: 11.6789
# Epoch 304/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.5269 - mae: 5.4078 - val_loss: 375.7414 - val_mae: 12.4227
# Epoch 305/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 77.2571 - mae: 5.9010 - val_loss: 338.4896 - val_mae: 11.4859
# Epoch 306/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59.0290 - mae: 5.2448 - val_loss: 341.9514 - val_mae: 12.1715
# Epoch 307/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.4491 - mae: 5.6755 - val_loss: 359.6348 - val_mae: 11.8212
# Epoch 308/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 87.1039 - mae: 6.3252 - val_loss: 351.6090 - val_mae: 11.5920
# Epoch 309/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 80.4211 - mae: 6.0778 - val_loss: 363.2713 - val_mae: 12.4574
# Epoch 310/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 87.9868 - mae: 6.3217 - val_loss: 346.9513 - val_mae: 11.7181
# Epoch 311/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.4142 - mae: 5.7427 - val_loss: 407.4409 - val_mae: 12.6076
# Epoch 312/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 217.5961 - mae: 9.8381 - val_loss: 366.6533 - val_mae: 13.6247
# Epoch 313/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 110.1962 - mae: 7.5104 - val_loss: 387.6376 - val_mae: 14.4960
# Epoch 314/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 126.4459 - mae: 8.4066 - val_loss: 407.4414 - val_mae: 12.8337
# Epoch 315/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 104.9103 - mae: 7.1805 - val_loss: 357.9083 - val_mae: 11.7908
# Epoch 316/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 88.4199 - mae: 5.8620 - val_loss: 344.5936 - val_mae: 11.7716
# Epoch 317/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 61.1902 - mae: 5.5067 - val_loss: 327.5694 - val_mae: 11.6861
# Epoch 318/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 61.3892 - mae: 5.4287 - val_loss: 326.6692 - val_mae: 11.7255
# Epoch 319/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 78.0350 - mae: 6.0266 - val_loss: 371.5243 - val_mae: 11.9582
# Epoch 320/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.0747 - mae: 5.5090 - val_loss: 335.6315 - val_mae: 11.8818
# Epoch 321/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 77.4390 - mae: 5.8180 - val_loss: 348.5333 - val_mae: 11.6613
# Epoch 322/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.8783 - mae: 5.5063 - val_loss: 307.7484 - val_mae: 11.4778
# Epoch 323/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 102.3029 - mae: 7.4316 - val_loss: 382.6239 - val_mae: 12.7943
# Epoch 324/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 81.9058 - mae: 6.4095 - val_loss: 362.1076 - val_mae: 11.9404
# Epoch 325/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.2298 - mae: 5.1512 - val_loss: 326.6916 - val_mae: 11.7547
# Epoch 326/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.6168 - mae: 5.3872 - val_loss: 328.0169 - val_mae: 11.6189
# Epoch 327/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 74.6789 - mae: 5.7441 - val_loss: 358.0352 - val_mae: 11.9503
# Epoch 328/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.0362 - mae: 5.2661 - val_loss: 333.9825 - val_mae: 11.5275
# Epoch 329/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69.0350 - mae: 5.4150 - val_loss: 327.9771 - val_mae: 11.6729
# Epoch 330/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 55.9582 - mae: 4.9781 - val_loss: 353.4224 - val_mae: 11.7050
# Epoch 331/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 61.6113 - mae: 5.3980 - val_loss: 328.7625 - val_mae: 11.5755
# Epoch 332/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.8784 - mae: 5.3661 - val_loss: 312.5694 - val_mae: 11.6940
# Epoch 333/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 88.6318 - mae: 6.4651 - val_loss: 390.5175 - val_mae: 14.1188
# Epoch 334/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 208.1023 - mae: 10.8748 - val_loss: 441.4624 - val_mae: 14.8646
# Epoch 335/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 171.6640 - mae: 9.9926 - val_loss: 500.1490 - val_mae: 15.2027
# Epoch 336/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 140.8388 - mae: 8.2205 - val_loss: 422.6526 - val_mae: 13.4948
# Epoch 337/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.7795 - mae: 5.9729 - val_loss: 367.1621 - val_mae: 12.4499
# Epoch 338/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 57.4757 - mae: 5.0898 - val_loss: 368.0614 - val_mae: 12.1429
# Epoch 339/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 76.2272 - mae: 5.8213 - val_loss: 346.1934 - val_mae: 12.1877
# Epoch 340/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 62.5297 - mae: 5.3092 - val_loss: 353.1906 - val_mae: 11.8624
# Epoch 341/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.4331 - mae: 5.6385 - val_loss: 357.1105 - val_mae: 11.6916
# Epoch 342/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 92.9305 - mae: 6.1297 - val_loss: 341.9857 - val_mae: 12.9325
# Epoch 343/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.6690 - mae: 5.7929 - val_loss: 343.9933 - val_mae: 11.9238
# Epoch 344/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.5393 - mae: 5.7145 - val_loss: 349.0335 - val_mae: 11.6666
# Epoch 345/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 60.3730 - mae: 5.0530 - val_loss: 324.1354 - val_mae: 11.5164
# Epoch 346/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.2228 - mae: 4.9262 - val_loss: 358.3955 - val_mae: 11.6638
# Epoch 347/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.9905 - mae: 5.2773 - val_loss: 357.3041 - val_mae: 11.6716
# Epoch 348/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59.2580 - mae: 4.8467 - val_loss: 352.5792 - val_mae: 11.6049
# Epoch 349/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 125.7358 - mae: 7.0219 - val_loss: 362.6270 - val_mae: 13.0155
# Epoch 350/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 77.0349 - mae: 6.3451 - val_loss: 333.8112 - val_mae: 11.5542
# Epoch 351/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.2722 - mae: 5.5313 - val_loss: 372.0840 - val_mae: 11.9519
# Epoch 352/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.6805 - mae: 5.1436 - val_loss: 340.1026 - val_mae: 11.4312
# Epoch 353/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 60.6882 - mae: 5.0466 - val_loss: 331.6240 - val_mae: 11.2275
# Epoch 354/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.5554 - mae: 4.4369 - val_loss: 307.2041 - val_mae: 11.4473
# Epoch 355/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 51.9335 - mae: 4.7035 - val_loss: 326.2320 - val_mae: 11.3227
# Epoch 356/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 51.2332 - mae: 4.4809 - val_loss: 318.7264 - val_mae: 11.0472
# Epoch 357/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.4673 - mae: 5.0790 - val_loss: 325.4594 - val_mae: 11.5386
# Epoch 358/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 97.4624 - mae: 6.5824 - val_loss: 459.1031 - val_mae: 13.9773
# Epoch 359/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 115.5482 - mae: 7.2590 - val_loss: 369.6690 - val_mae: 12.2267
# Epoch 360/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 75.2020 - mae: 5.8684 - val_loss: 370.1263 - val_mae: 12.0841
# Epoch 361/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71.1226 - mae: 5.7959 - val_loss: 307.2836 - val_mae: 11.6812
# Epoch 362/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 58.1726 - mae: 5.3094 - val_loss: 330.0104 - val_mae: 11.6308
# Epoch 363/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51.4852 - mae: 4.7501 - val_loss: 305.7157 - val_mae: 11.3729
# Epoch 364/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59.1334 - mae: 5.0617 - val_loss: 326.3374 - val_mae: 11.3281
# Epoch 365/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.3777 - mae: 4.2108 - val_loss: 326.8989 - val_mae: 11.7547
# Epoch 366/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 87.9420 - mae: 6.5339 - val_loss: 354.8391 - val_mae: 11.8205
# Epoch 367/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 72.0723 - mae: 5.6971 - val_loss: 347.0670 - val_mae: 11.4229
# Epoch 368/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 56.4368 - mae: 4.9946 - val_loss: 361.9548 - val_mae: 11.9137
# Epoch 369/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 55.1217 - mae: 5.2336 - val_loss: 351.5277 - val_mae: 11.5234
# Epoch 370/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 142.2594 - mae: 8.0424 - val_loss: 366.4812 - val_mae: 12.2085
# Epoch 371/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 74.5719 - mae: 6.2339 - val_loss: 306.4298 - val_mae: 11.6751
# Epoch 372/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 60.9496 - mae: 5.4504 - val_loss: 329.3778 - val_mae: 11.4779
# Epoch 373/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.2527 - mae: 5.8294 - val_loss: 352.6437 - val_mae: 12.2006
# Epoch 374/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 84.0053 - mae: 6.4906 - val_loss: 342.4352 - val_mae: 11.8604
# Epoch 375/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70.5112 - mae: 5.4596 - val_loss: 304.6143 - val_mae: 11.7818
# Epoch 376/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.8057 - mae: 5.9089 - val_loss: 363.4402 - val_mae: 12.6882
# Epoch 377/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 109.9074 - mae: 7.0778 - val_loss: 320.3047 - val_mae: 11.7079
# Epoch 378/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 70.2566 - mae: 6.2000 - val_loss: 344.7306 - val_mae: 11.6490
# Epoch 379/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59.7564 - mae: 5.0311 - val_loss: 360.0381 - val_mae: 11.7284
# Epoch 380/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 71.6915 - mae: 5.9266 - val_loss: 330.6491 - val_mae: 11.6679
# Epoch 381/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.2568 - mae: 4.8824 - val_loss: 322.4406 - val_mae: 10.9455
# Epoch 382/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 52.8961 - mae: 4.6609 - val_loss: 321.1803 - val_mae: 11.2057
# Epoch 383/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.5467 - mae: 4.5581 - val_loss: 337.7292 - val_mae: 11.5070
# Epoch 384/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.6267 - mae: 4.5492 - val_loss: 320.3418 - val_mae: 12.3865
# Epoch 385/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 311.2581 - mae: 11.1664 - val_loss: 518.9605 - val_mae: 16.4875
# Epoch 386/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 207.1913 - mae: 10.7573 - val_loss: 422.1862 - val_mae: 14.0538
# Epoch 387/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 152.5191 - mae: 9.6940 - val_loss: 421.2020 - val_mae: 13.5709
# Epoch 388/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 91.3916 - mae: 6.9069 - val_loss: 403.6331 - val_mae: 12.9607
# Epoch 389/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 120.2527 - mae: 6.7625 - val_loss: 475.0118 - val_mae: 13.3176
# Epoch 390/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 145.3123 - mae: 7.6527 - val_loss: 362.0313 - val_mae: 12.1370
# Epoch 391/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 76.9385 - mae: 6.2172 - val_loss: 381.3096 - val_mae: 12.5651
# Epoch 392/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 61.7640 - mae: 5.5637 - val_loss: 352.4979 - val_mae: 11.9538
# Epoch 393/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.8458 - mae: 4.9907 - val_loss: 337.3246 - val_mae: 11.5929
# Epoch 394/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.1765 - mae: 4.5869 - val_loss: 344.3836 - val_mae: 11.5835
# Epoch 395/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.8183 - mae: 4.6523 - val_loss: 358.9801 - val_mae: 11.8761
# Epoch 396/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 119.8255 - mae: 7.0551 - val_loss: 352.2389 - val_mae: 12.1863
# Epoch 397/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.8265 - mae: 5.4876 - val_loss: 345.4626 - val_mae: 12.2337
# Epoch 398/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.7144 - mae: 5.6102 - val_loss: 324.2140 - val_mae: 11.7976
# Epoch 399/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.4354 - mae: 4.9750 - val_loss: 337.2677 - val_mae: 12.0025
# Epoch 400/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.2650 - mae: 5.2569 - val_loss: 324.6881 - val_mae: 11.3140
# Epoch 401/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.9478 - mae: 4.8342 - val_loss: 322.5670 - val_mae: 11.2312
# Epoch 402/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.1145 - mae: 4.2973 - val_loss: 330.4252 - val_mae: 11.3977
# Epoch 403/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.6215 - mae: 4.1938 - val_loss: 330.9571 - val_mae: 11.1640
# Epoch 404/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 57.3691 - mae: 4.6507 - val_loss: 319.8653 - val_mae: 11.2180
# Epoch 405/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 64.4452 - mae: 5.2831 - val_loss: 348.1948 - val_mae: 11.4245
# Epoch 406/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 60.6301 - mae: 4.9438 - val_loss: 318.7864 - val_mae: 11.2136
# Epoch 407/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.8914 - mae: 4.4072 - val_loss: 319.5141 - val_mae: 11.2532
# Epoch 408/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 49.0212 - mae: 4.4861 - val_loss: 326.4048 - val_mae: 11.2514
# Epoch 409/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 60.0708 - mae: 4.5837 - val_loss: 338.5143 - val_mae: 11.2044
# Epoch 410/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.5197 - mae: 4.0265 - val_loss: 336.6124 - val_mae: 11.2332
# Epoch 411/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50.7645 - mae: 4.2081 - val_loss: 326.1622 - val_mae: 11.1854
# Epoch 412/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.1354 - mae: 3.8096 - val_loss: 309.6371 - val_mae: 11.5520
# Epoch 413/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 60.4922 - mae: 5.3485 - val_loss: 346.4390 - val_mae: 12.0136
# Epoch 414/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69.5038 - mae: 5.6880 - val_loss: 345.8286 - val_mae: 11.3739
# Epoch 415/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 64.0287 - mae: 5.2563 - val_loss: 364.2052 - val_mae: 11.6601
# Epoch 416/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.4912 - mae: 4.3054 - val_loss: 316.5832 - val_mae: 11.8403
# Epoch 417/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 61.2809 - mae: 5.3113 - val_loss: 321.6446 - val_mae: 11.3925
# Epoch 418/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 51.0896 - mae: 4.7887 - val_loss: 316.0753 - val_mae: 11.0868
# Epoch 419/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.9095 - mae: 4.2914 - val_loss: 330.2461 - val_mae: 11.1523
# Epoch 420/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.9098 - mae: 4.0702 - val_loss: 342.7428 - val_mae: 11.4595
# Epoch 421/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 57.7879 - mae: 4.6818 - val_loss: 335.4309 - val_mae: 11.4794
# Epoch 422/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.9082 - mae: 4.2393 - val_loss: 338.3197 - val_mae: 11.7969
# Epoch 423/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.2237 - mae: 4.4800 - val_loss: 326.7113 - val_mae: 11.2933
# Epoch 424/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.9895 - mae: 4.0276 - val_loss: 309.1070 - val_mae: 11.1185
# Epoch 425/1000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 43.0380 - mae: 4.1663 - val_loss: 337.7572 - val_mae: 11.3123
# Epoch 425: early stopping
# Restoring model weights from the end of the best epoch: 375.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#   model  R2_train  MAE_train  MAPE_train  RMSE_train   R2_test  MAE_test  \
# 0   ANN  0.907921   7.810719    8.953937   11.911607  0.897605  9.176896
#
#    MAPE_test  RMSE_test
# 0   10.79565  12.637538

# %%
metrics = pd.concat([lr_metrics, svr_metrics, rfr_metrics, gbr_metrics, xgb_metrics, ann_metrics])
metrics.to_markdown('output/report/report_models_reduced.md', index=False, tablefmt='github')
metrics
# Out:
#                model  R2_train  MAE_train  MAPE_train  RMSE_train   R2_test  \
# 0  Linear Regression  0.368366  23.531420   34.331034   31.197682  0.452770
# 0                SVR  0.907250   6.086613    5.642222   11.954914  0.868283
# 0      Randon Forest  0.980705   3.625796    4.760953    5.452702  0.911245
# 0                GBR  0.997963   1.265646    1.583380    1.771753  0.964033
# 0            XGBoost  0.994633   2.051741    2.642526    2.875845  0.967404
# 0                ANN  0.907921   7.810719    8.953937   11.911607  0.897605
#
#     MAE_test  MAPE_test  RMSE_test
# 0  22.477543  32.641922  29.215163
# 0   9.288821  11.029474  14.333248
# 0   7.856233  10.296883  11.765769
# 0   5.009957   6.061530   7.489926
# 0   5.349314   6.850985   7.130297
# 0   9.176896  10.795650  12.637538
